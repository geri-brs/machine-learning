# %%
## written by tutorial
from sklearn import datasets

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %%
iris = datasets.load_iris()

# %%
print(type(iris))
# Out:
# <class 'sklearn.utils.Bunch'>

# %%
print(iris.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
X = iris.data

# %%
y = iris.target

# %%
df = pd.DataFrame(X, columns = iris.feature_names)

# %%
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print(pd.scatter_matrix(df, c=y, figsize=[8,8], s=150, marker='D'))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.
# [[<matplotlib.axes._subplots.AxesSubplot object at 0x000002369FB0B940>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002369FDE9B70>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002369FE1BCF8>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002369FE4FE48>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000002369FE94048>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002369FE94080>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002369FE9AC18>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002369FF2BF28>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x000002369FF70048>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002369FFA5208>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x000002369FFDE358>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000236A0006978>]
#  [<matplotlib.axes._subplots.AxesSubplot object at 0x00000236A003AF98>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000236A007E128>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000236A00B6128>
#   <matplotlib.axes._subplots.AxesSubplot object at 0x00000236A00879E8>]]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=6)

# %%
knn.fit(iris['data'], iris['target'])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=6, p=2,
#            weights='uniform')

# %%
print(iris['data'].shape)
# Out:
# (150, 4)

# %%
print(iris['target'].shape)
# Out:
# (150,)

# %%
X_new = np.array([[5.7, 3.0, 1.2, 0.6], [5.0, 3.9, 4.0, 1.0], [6.3, 2.7, 4.1, 2.1]])

# %%
prediction = knn.predict(X_new)

# %%
print('Prediction {}'.format(prediction))
print(iris.target_names)
# Out:
# Prediction [0 1 1]
# ['setosa' 'versicolor' 'virginica']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=21, stratify=y)

# %%
knn = KNeighborsClassifier(n_neighbors=8)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=8, p=2,
#            weights='uniform')

# %%
y_pred = knn.predict(X_test)

# %%
print("Test set predictions:\n {}".format(y_pred))
# Out:
# Test set predictions:
#  [2 1 2 2 1 0 1 0 0 1 0 2 0 2 2 0 0 0 1 0 2 2 2 0 1 1 1 0 0 1 2 2 0 0 1 2 2
#  1 1 2 1 1 0 2 1]

# %%
print(knn.score(X_test, y_test))
# Out:
# 0.9555555555555556
