# %%
# Upload dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c17ac555-1765-4121-a101-cb13a19c78bb" name="files[]" multiple disabled />
#      <output id="result-c17ac555-1765-4121-a101-cb13a19c78bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data-house-pricing-train.csv to data-house-pricing-train.csv

# %%
# %matplotlib inline
import numpy
import pandas            as pd
import matplotlib.pyplot as plt
import tensorflow        as tf
from   tensorflow.keras           import layers
from   tensorflow.keras.callbacks import EarlyStopping
from   sklearn.preprocessing      import LabelEncoder, OneHotEncoder, StandardScaler
from   sklearn.model_selection    import train_test_split
from   sklearn.feature_selection  import SelectKBest
from   sklearn.feature_selection  import chi2
from   sklearn.ensemble           import ExtraTreesClassifier
from   sklearn.model_selection    import train_test_split
from   sklearn                    import linear_model
from   sklearn.linear_model       import LinearRegression
from   sklearn                    import metrics
from   sklearn.model_selection    import cross_val_score
from   sklearn.model_selection    import KFold
from   sklearn.pipeline           import Pipeline
from   sklearn.preprocessing      import MinMaxScaler
from   keras.models               import Sequential
from   keras.layers               import Dense, Dropout
from   tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor
# Out:
# Using TensorFlow backend.

# %%
print("Versions:")
print("Tensorflow:", tf.VERSION)
# 1.14.0-rc1
print("Keras: ", tf.keras.__version__)
#2.2.4-tf
# Out:
# Versions:
# Tensorflow: 1.14.0
# Keras:  2.2.4-tf

# %%
# Load house-pricing dataset
path = "./data-house-pricing-train.csv"
dataset = pd.read_csv(path)

# %%
# Function replace object typed columns with int64 typed columns by one hot encoding method
def one_hot_encoding(dataset, column_index, row_length):
  y = dataset.iloc[:, column_index].values
  le = LabelEncoder()
  y = le.fit_transform(y)
  y = pd.Series(y.reshape(row_length,))
  return y

# %%
# Collect categorical values to make binary variables
categorical_columns = []
for i in dataset.columns.values:
    if(dataset[i].dtype == 'object'):
        categorical_columns.append(i)

# %%
# Handle NaN values of dataset
def handling_NaN(dataset):
    features = dataset.columns.values
    row_length = len(dataset)
  
    for j, feature in enumerate(features):
        if (dataset[feature].dtype == 'int64' or dataset[feature].dtype == 'float64'):
            dataset[feature].fillna(dataset[feature].mean(), inplace = True)
        
    for i, feature in enumerate(features):
        if (dataset[feature].dtype == 'object'):
            dataset[feature].fillna("NA", inplace = True)
        
    return dataset

# %%
dataset = handling_NaN(dataset)

for k, feature in enumerate(dataset.columns.values):
    dataset[feature] = one_hot_encoding(dataset, k, len(dataset))

# %%
dataset.head()
# Out:
#    Id  MSSubClass  MSZoning  ...  SaleType  SaleCondition  SalePrice
# 0   0           5         3  ...         8              4        412
# 1   1           0         3  ...         8              4        339
# 2   2           5         3  ...         8              4        442
# 3   3           6         3  ...         8              0        194
# 4   4           5         3  ...         8              4        494
#
# [5 rows x 81 columns]

# %%
# Feature selection no.1 (feature importance)
del dataset['Id']
print(dataset.shape)

X = dataset.iloc[:,0:79]  #independent columns
y = dataset.iloc[:,-1]    #target column i.e price range

model = ExtraTreesClassifier()
model.fit(X,y)

feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.show()
# Out:
# (1460, 80)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Feature selection no.2 (univariate selection)
X = dataset.iloc[:,0:79]  #independent columns
y = dataset.iloc[:,-1]    #target column i.e price range

#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)

#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#           Specs          Score
# 33   BsmtFinSF1  175046.761502
# 43     2ndFlrSF  156662.356995
# 3       LotArea  153258.463160
# 45    GrLivArea  152684.196937
# 37  TotalBsmtSF  128216.765944
# 42     1stFlrSF  121988.499739
# 25   MasVnrArea  120022.908755
# 36    BsmtUnfSF  115155.926925
# 61   GarageArea   81454.454930
# 65   WoodDeckSF   71779.273592

# %%
# Generate dummy variables and remove unnecessary columns
def generate_dummies(df, dummy_column):
    dummies = pd.get_dummies(df[dummy_column], prefix=dummy_column)
    df = pd.concat([df, dummies], axis=1)
    return df

X = pd.DataFrame.copy(dataset)

for column in categorical_columns:
    X = generate_dummies(X, column)
    
for column in categorical_columns:
    del X[column]

# %%
X.head()
# Out:
#    MSSubClass  LotFrontage  ...  SaleCondition_4  SaleCondition_5
# 0           5           36  ...                1                0
# 1           0           52  ...                1                0
# 2           5           39  ...                1                0
# 3           6           31  ...                0                0
# 4           5           56  ...                1                0
#
# [5 rows x 305 columns]

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# Create a keras model and make a summary
model = Sequential()
model.add(Dense(300, input_dim=305, kernel_initializer='normal', activation='relu'))
model.add(Dense(300, activation='relu'))
model.add(Dense(1, activation='linear'))
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 300)               91800
# _________________________________________________________________
# dense_5 (Dense)              (None, 300)               90300
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 301
# =================================================================
# Total params: 182,401
# Trainable params: 182,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
model.compile(loss='mse', optimizer='adam', metrics=['mse','mae'])

# %%
#Set early stopping monitor
early_stopping_monitor = EarlyStopping(patience=3)

# Train model
history = model.fit(X_train,
                    y_train, 
                    validation_split=0.2,
                    epochs=100, 
                    batch_size=300,  
                    callbacks = [early_stopping_monitor],
                    verbose=1)
# Out:
# W0705 08:59:17.776858 139825588406144 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Train on 934 samples, validate on 234 samples
# Epoch 1/100
# 934/934 [==============================] - 0s 489us/step - loss: 80045.7142 - mean_squared_error: 80045.7142 - mean_absolute_error: 232.0077 - val_loss: 7985.2388 - val_mean_squared_error: 7985.2388 - val_mean_absolute_error: 70.1538
# Epoch 2/100
# 934/934 [==============================] - 0s 80us/step - loss: 18200.1265 - mean_squared_error: 18200.1265 - mean_absolute_error: 107.4144 - val_loss: 20611.9336 - val_mean_squared_error: 20611.9336 - val_mean_absolute_error: 119.9645
# Epoch 3/100
# 934/934 [==============================] - 0s 77us/step - loss: 16523.2523 - mean_squared_error: 16523.2523 - mean_absolute_error: 103.4857 - val_loss: 6521.5562 - val_mean_squared_error: 6521.5562 - val_mean_absolute_error: 64.8847
# Epoch 4/100
# 934/934 [==============================] - 0s 82us/step - loss: 7246.6140 - mean_squared_error: 7246.6140 - mean_absolute_error: 68.5614 - val_loss: 11219.9141 - val_mean_squared_error: 11219.9141 - val_mean_absolute_error: 85.9512
# Epoch 5/100
# 934/934 [==============================] - 0s 83us/step - loss: 9965.4918 - mean_squared_error: 9965.4918 - mean_absolute_error: 80.5539 - val_loss: 8734.8760 - val_mean_squared_error: 8734.8760 - val_mean_absolute_error: 75.8807
# Epoch 6/100
# 934/934 [==============================] - 0s 82us/step - loss: 6599.1114 - mean_squared_error: 6599.1114 - mean_absolute_error: 65.3313 - val_loss: 3868.2993 - val_mean_squared_error: 3868.2993 - val_mean_absolute_error: 49.3390
# Epoch 7/100
# 934/934 [==============================] - 0s 80us/step - loss: 4353.0194 - mean_squared_error: 4353.0194 - mean_absolute_error: 49.6972 - val_loss: 4115.9790 - val_mean_squared_error: 4115.9790 - val_mean_absolute_error: 48.9034
# Epoch 8/100
# 934/934 [==============================] - 0s 80us/step - loss: 4539.4415 - mean_squared_error: 4539.4415 - mean_absolute_error: 49.8707 - val_loss: 2604.3176 - val_mean_squared_error: 2604.3176 - val_mean_absolute_error: 38.7856
# Epoch 9/100
# 934/934 [==============================] - 0s 80us/step - loss: 2910.3082 - mean_squared_error: 2910.3082 - mean_absolute_error: 40.4336 - val_loss: 3354.7227 - val_mean_squared_error: 3354.7227 - val_mean_absolute_error: 46.2478
# Epoch 10/100
# 934/934 [==============================] - 0s 82us/step - loss: 3084.4383 - mean_squared_error: 3084.4383 - mean_absolute_error: 44.1907 - val_loss: 2030.8328 - val_mean_squared_error: 2030.8328 - val_mean_absolute_error: 34.7842
# Epoch 11/100
# 934/934 [==============================] - 0s 81us/step - loss: 2052.9188 - mean_squared_error: 2052.9188 - mean_absolute_error: 33.6708 - val_loss: 1731.5360 - val_mean_squared_error: 1731.5360 - val_mean_absolute_error: 30.6276
# Epoch 12/100
# 934/934 [==============================] - 0s 80us/step - loss: 1789.9654 - mean_squared_error: 1789.9654 - mean_absolute_error: 30.0765 - val_loss: 1188.8726 - val_mean_squared_error: 1188.8726 - val_mean_absolute_error: 26.1649
# Epoch 13/100
# 934/934 [==============================] - 0s 82us/step - loss: 1247.2236 - mean_squared_error: 1247.2236 - mean_absolute_error: 26.2161 - val_loss: 974.7863 - val_mean_squared_error: 974.7863 - val_mean_absolute_error: 23.9815
# Epoch 14/100
# 934/934 [==============================] - 0s 82us/step - loss: 863.3537 - mean_squared_error: 863.3537 - mean_absolute_error: 21.3995 - val_loss: 766.0822 - val_mean_squared_error: 766.0822 - val_mean_absolute_error: 20.7962
# Epoch 15/100
# 934/934 [==============================] - 0s 82us/step - loss: 626.9796 - mean_squared_error: 626.9796 - mean_absolute_error: 18.3498 - val_loss: 573.2633 - val_mean_squared_error: 573.2633 - val_mean_absolute_error: 18.4943
# Epoch 16/100
# 934/934 [==============================] - 0s 92us/step - loss: 420.5860 - mean_squared_error: 420.5860 - mean_absolute_error: 15.7535 - val_loss: 401.0891 - val_mean_squared_error: 401.0891 - val_mean_absolute_error: 15.4563
# Epoch 17/100
# 934/934 [==============================] - 0s 87us/step - loss: 314.0324 - mean_squared_error: 314.0324 - mean_absolute_error: 13.7635 - val_loss: 297.1937 - val_mean_squared_error: 297.1937 - val_mean_absolute_error: 13.3459
# Epoch 18/100
# 934/934 [==============================] - 0s 82us/step - loss: 222.5570 - mean_squared_error: 222.5570 - mean_absolute_error: 11.8387 - val_loss: 214.8963 - val_mean_squared_error: 214.8963 - val_mean_absolute_error: 11.3889
# Epoch 19/100
# 934/934 [==============================] - 0s 82us/step - loss: 168.9393 - mean_squared_error: 168.9393 - mean_absolute_error: 10.1478 - val_loss: 162.0523 - val_mean_squared_error: 162.0523 - val_mean_absolute_error: 9.8755
# Epoch 20/100
# 934/934 [==============================] - 0s 83us/step - loss: 129.5189 - mean_squared_error: 129.5189 - mean_absolute_error: 8.8689 - val_loss: 134.3496 - val_mean_squared_error: 134.3496 - val_mean_absolute_error: 8.8701
# Epoch 21/100
# 934/934 [==============================] - 0s 81us/step - loss: 102.5869 - mean_squared_error: 102.5869 - mean_absolute_error: 7.6071 - val_loss: 110.2035 - val_mean_squared_error: 110.2035 - val_mean_absolute_error: 8.1441
# Epoch 22/100
# 934/934 [==============================] - 0s 74us/step - loss: 92.1565 - mean_squared_error: 92.1565 - mean_absolute_error: 7.5233 - val_loss: 120.2722 - val_mean_squared_error: 120.2722 - val_mean_absolute_error: 8.5425
# Epoch 23/100
# 934/934 [==============================] - 0s 82us/step - loss: 82.7915 - mean_squared_error: 82.7915 - mean_absolute_error: 7.0429 - val_loss: 86.7862 - val_mean_squared_error: 86.7862 - val_mean_absolute_error: 7.3010
# Epoch 24/100
# 934/934 [==============================] - 0s 76us/step - loss: 70.5087 - mean_squared_error: 70.5087 - mean_absolute_error: 6.5580 - val_loss: 87.5419 - val_mean_squared_error: 87.5419 - val_mean_absolute_error: 7.1934
# Epoch 25/100
# 934/934 [==============================] - 0s 80us/step - loss: 60.1826 - mean_squared_error: 60.1826 - mean_absolute_error: 5.8968 - val_loss: 60.3561 - val_mean_squared_error: 60.3561 - val_mean_absolute_error: 6.0155
# Epoch 26/100
# 934/934 [==============================] - 0s 74us/step - loss: 50.4773 - mean_squared_error: 50.4773 - mean_absolute_error: 5.3986 - val_loss: 57.7501 - val_mean_squared_error: 57.7501 - val_mean_absolute_error: 5.8167
# Epoch 27/100
# 934/934 [==============================] - 0s 76us/step - loss: 42.1750 - mean_squared_error: 42.1750 - mean_absolute_error: 5.0093 - val_loss: 51.2477 - val_mean_squared_error: 51.2477 - val_mean_absolute_error: 5.5424
# Epoch 28/100
# 934/934 [==============================] - 0s 72us/step - loss: 39.0471 - mean_squared_error: 39.0471 - mean_absolute_error: 4.8443 - val_loss: 46.7792 - val_mean_squared_error: 46.7792 - val_mean_absolute_error: 5.2633
# Epoch 29/100
# 934/934 [==============================] - 0s 74us/step - loss: 34.4182 - mean_squared_error: 34.4182 - mean_absolute_error: 4.5021 - val_loss: 40.3460 - val_mean_squared_error: 40.3460 - val_mean_absolute_error: 4.9564
# Epoch 30/100
# 934/934 [==============================] - 0s 73us/step - loss: 31.5786 - mean_squared_error: 31.5786 - mean_absolute_error: 4.3194 - val_loss: 35.5607 - val_mean_squared_error: 35.5607 - val_mean_absolute_error: 4.5546
# Epoch 31/100
# 934/934 [==============================] - 0s 80us/step - loss: 28.2768 - mean_squared_error: 28.2768 - mean_absolute_error: 4.0799 - val_loss: 33.2792 - val_mean_squared_error: 33.2792 - val_mean_absolute_error: 4.4164
# Epoch 32/100
# 934/934 [==============================] - 0s 76us/step - loss: 25.6080 - mean_squared_error: 25.6080 - mean_absolute_error: 3.8492 - val_loss: 31.3299 - val_mean_squared_error: 31.3299 - val_mean_absolute_error: 4.3154
# Epoch 33/100
# 934/934 [==============================] - 0s 76us/step - loss: 24.0092 - mean_squared_error: 24.0092 - mean_absolute_error: 3.7012 - val_loss: 30.0219 - val_mean_squared_error: 30.0219 - val_mean_absolute_error: 4.1582
# Epoch 34/100
# 934/934 [==============================] - 0s 73us/step - loss: 22.2359 - mean_squared_error: 22.2359 - mean_absolute_error: 3.5654 - val_loss: 25.8842 - val_mean_squared_error: 25.8842 - val_mean_absolute_error: 3.8877
# Epoch 35/100
# 934/934 [==============================] - 0s 73us/step - loss: 20.4722 - mean_squared_error: 20.4722 - mean_absolute_error: 3.4384 - val_loss: 25.0981 - val_mean_squared_error: 25.0981 - val_mean_absolute_error: 3.7995
# Epoch 36/100
# 934/934 [==============================] - 0s 86us/step - loss: 19.1991 - mean_squared_error: 19.1991 - mean_absolute_error: 3.3173 - val_loss: 25.4418 - val_mean_squared_error: 25.4418 - val_mean_absolute_error: 3.8580
# Epoch 37/100
# 934/934 [==============================] - 0s 75us/step - loss: 18.5737 - mean_squared_error: 18.5737 - mean_absolute_error: 3.2575 - val_loss: 24.4997 - val_mean_squared_error: 24.4997 - val_mean_absolute_error: 3.7373
# Epoch 38/100
# 934/934 [==============================] - 0s 80us/step - loss: 17.5527 - mean_squared_error: 17.5527 - mean_absolute_error: 3.1533 - val_loss: 24.1903 - val_mean_squared_error: 24.1903 - val_mean_absolute_error: 3.7009
# Epoch 39/100
# 934/934 [==============================] - 0s 79us/step - loss: 17.4450 - mean_squared_error: 17.4450 - mean_absolute_error: 3.1691 - val_loss: 21.5685 - val_mean_squared_error: 21.5685 - val_mean_absolute_error: 3.5130
# Epoch 40/100
# 934/934 [==============================] - 0s 67us/step - loss: 17.1457 - mean_squared_error: 17.1457 - mean_absolute_error: 3.1525 - val_loss: 21.9341 - val_mean_squared_error: 21.9341 - val_mean_absolute_error: 3.6855
# Epoch 41/100
# 934/934 [==============================] - 0s 74us/step - loss: 15.9521 - mean_squared_error: 15.9521 - mean_absolute_error: 3.0651 - val_loss: 20.0360 - val_mean_squared_error: 20.0360 - val_mean_absolute_error: 3.4308
# Epoch 42/100
# 934/934 [==============================] - 0s 73us/step - loss: 14.6609 - mean_squared_error: 14.6609 - mean_absolute_error: 2.9275 - val_loss: 21.3234 - val_mean_squared_error: 21.3234 - val_mean_absolute_error: 3.5035
# Epoch 43/100
# 934/934 [==============================] - 0s 72us/step - loss: 14.5394 - mean_squared_error: 14.5394 - mean_absolute_error: 2.8779 - val_loss: 18.9048 - val_mean_squared_error: 18.9048 - val_mean_absolute_error: 3.3200
# Epoch 44/100
# 934/934 [==============================] - 0s 71us/step - loss: 13.7366 - mean_squared_error: 13.7366 - mean_absolute_error: 2.8450 - val_loss: 17.7867 - val_mean_squared_error: 17.7867 - val_mean_absolute_error: 3.1800
# Epoch 45/100
# 934/934 [==============================] - 0s 71us/step - loss: 12.5533 - mean_squared_error: 12.5533 - mean_absolute_error: 2.6866 - val_loss: 18.0030 - val_mean_squared_error: 18.0030 - val_mean_absolute_error: 3.1669
# Epoch 46/100
# 934/934 [==============================] - 0s 82us/step - loss: 12.2008 - mean_squared_error: 12.2008 - mean_absolute_error: 2.6431 - val_loss: 18.1943 - val_mean_squared_error: 18.1943 - val_mean_absolute_error: 3.2682
# Epoch 47/100
# 934/934 [==============================] - 0s 72us/step - loss: 11.7814 - mean_squared_error: 11.7814 - mean_absolute_error: 2.5921 - val_loss: 16.3447 - val_mean_squared_error: 16.3447 - val_mean_absolute_error: 3.0443
# Epoch 48/100
# 934/934 [==============================] - 0s 76us/step - loss: 10.9785 - mean_squared_error: 10.9785 - mean_absolute_error: 2.5048 - val_loss: 15.9849 - val_mean_squared_error: 15.9849 - val_mean_absolute_error: 3.0185
# Epoch 49/100
# 934/934 [==============================] - 0s 83us/step - loss: 10.5983 - mean_squared_error: 10.5983 - mean_absolute_error: 2.4639 - val_loss: 17.1628 - val_mean_squared_error: 17.1628 - val_mean_absolute_error: 3.1769
# Epoch 50/100
# 934/934 [==============================] - 0s 78us/step - loss: 11.2466 - mean_squared_error: 11.2466 - mean_absolute_error: 2.5742 - val_loss: 16.0669 - val_mean_squared_error: 16.0669 - val_mean_absolute_error: 3.0480
# Epoch 51/100
# 934/934 [==============================] - 0s 70us/step - loss: 10.9547 - mean_squared_error: 10.9547 - mean_absolute_error: 2.5161 - val_loss: 16.9783 - val_mean_squared_error: 16.9783 - val_mean_absolute_error: 3.1158

# %%
# Plot results
print(history.history.keys())
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mean_squared_error', 'val_mean_absolute_error', 'loss', 'mean_squared_error', 'mean_absolute_error'])

# %%
# evaluate the model
score = model.evaluate(X_train, y_train, verbose=1)

print("%s: %.2f%%" % (model.metrics_names[2], score[2]))
print("%s: %.2f%%" % (model.metrics_names[1], score[1]))
# Out:
# 1168/1168 [==============================] - 0s 40us/step
# mean_absolute_error: 2.67%
# mean_squared_error: 12.23%
